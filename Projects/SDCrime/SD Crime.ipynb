# %%
import pandas as pd
import pandas.io.data
from pandas import Series, DataFrame

import numpy as np

import datetime

import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
crime = pd.read_csv('incidents-2007.csv')

# %%
for x in range(8,14):
    year = 2000+x
    crimeb = pd.read_csv('incidents-'+str(year)+'.csv')
    crime.append(crimeb, ignore_index = True)
    print(crime)
    break
# Out:
#     id        date  year  month   day  week  dow      time  hour  is_night  \
# 0  NaN  2007-01-01  2007      1  2557     1    1  00:00:00     0         1
# 1  NaN  2007-01-01  2007      1  2557     1    1  00:00:00     0         1
# 2  NaN  2007-01-01  2007      1  2557     1    1  00:00:00     0         1
# 3  NaN  2007-01-01  2007      1  2557     1    1  00:00:00     0         1
# 4  NaN  2007-01-01  2007      1  2557     1    1  00:00:00     0         1
# 5  NaN  2007-01-01  2007      1  2557     1    1  00:00:00     0         1
# 6  NaN  2007-01-01  2007      1  2557     1    1  00:00:00     0         1
# 7  NaN  2007-01-01  2007      1  2557     1    1  00:00:00     0         1
# 8  NaN  2007-01-01  2007      1  2557     1    1  00:00:00     0         1
# 9  NaN  2007-01-01  2007      1  2557     1    1  00:00:00     0         1
# 10 NaN  2007-01-01  2007      1  2557     1    1  00:00:00     0         1
# ...

# %%
crime.count()
# Out:
# id                 0
# date           10812
# year           10812
# month          10812
# day            10812
# week           10812
# dow            10812
# time           10812
# hour           10812
# is_night       10812
# type           10808
# address        10812
# city           10812
# segment_id     10812
# nbrhood        10812
# community      10812
# comm_pop       10812
# council        10812
# council_pop    10812
# asr_zone          36
# lampdist          36
# lat            10812
# lon            10812
# desc           10805
# gctype         10812
# gcquality      10812
# dtype: int64
